# %%
# %matplotlib notebook

# %%
import numpy as np
from spotlob.register import ProcessRegister as prg
from spotlob.defaults import *

# %%
gui = make_gui('/mnt/lasershare/notebooks/fabi/pp/ultrafast VIS VIS/threshold/runA/bilder/Bild--16.jpg')

# %%
def my_threshold(image, lower_threshold, upper_threshold, invert):
    out = np.logical_and( image > lower_threshold, image < upper_threshold).astype(np.uint8)*255
    if invert:
        out = ~out
    return out

# %%
@use_in(gui)
@prg.binarisation_plugin([("lower_threshold",(0,255,100)), ("upper_threshold",(0,255,200)), ("invert", True)])
def my_threshold(image, lower_threshold, upper_threshold, invert):
    out = np.logical_and( image > lower_threshold, image < upper_threshold).astype(np.uint8)*255
    if invert:
        out = ~out
    return out

# %%
show_gui(gui)
# Out:
# <img src="data:image/png;base64,..." width="800">
# VkJveChjaGlsZHJlbj0oVkJveCgpLCBWQm94KGNoaWxkcmVuPShEcm9wZG93bihkZXNjcmlwdGlvbj11J2NvbnZlcnNpb24nLCBvcHRpb25zPSgnR3JleScsICdIdWUnLCAnU2F0dXJhdGlvbifigKY=
# Button(description=u'Evaluate', style=ButtonStyle())

# %%
mypipe = gui.pipeline
mypipe.save("test_portable_extended_pipe.pipe")

# %%
gui.results()
# Out:
#     area_px2  ellipse_angle  ellipse_majorAxis_px  ellipse_minorAxis_px  \
# 0  2289007.5      99.341728           1525.485229           1911.013428
#
#               ellipse_position_px
# 0  (1291.55334473, 1015.67718506)
