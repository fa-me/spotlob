# %%
import sys
sys.path.append("..")

# %%
# %matplotlib notebook

# %%
import spotlob
from spotlob.defaults import *
from spotlob.process_opencv import BinaryThreshold

# %%
filename = "hair.png"

# %%
gui = make_gui(filename, mode="line")

# %%
gui.pipeline = gui.pipeline.replaced_with(BinaryThreshold(100))

# %%
show_gui(gui)
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">
# VBox(children=(VBox(), VBox(children=(Dropdown(description='conversion', options=('Grey', 'Hue', 'Saturation',…
# Button(description='Evaluate', style=ButtonStyle())

# %%
results = gui.results()

# %%
from spotlob.calibration import Calibration

cal = Calibration(4.23)

# %%
cal.calibrate(results)
# Out:
#    area_px2  linewidth_px                                        line_params  \
# 0     52906     88.837082  [[406.85385], [195.01486], [0.78549486], [0.61...
#
#                                       distances_hist  \
# 0  [1439, 1440, 1442, 1439, 1441, 1440, 1438, 144...
#
#                               distances_bin_edges_px     area_um2  \
# 0  [0.0, 1.1138452863458843, 2.2276905726917686, ...  2956.815273
#
#    linewidth_um                             distances_bin_edges_um
# 0     21.001674  [0.0, 0.2633203986633296, 0.5266407973266592, ...

# %%
import matplotlib.pyplot as plt

dist = results.loc[0,"distances_hist"]
bins_edges = results.loc[0,"distances_bin_edges_um"]
lwh = results.loc[0,"linewidth_um"]/2.0

plt.figure()
plt.plot(bins_edges[1:], dist)
plt.axvline(lwh)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %m
# Out:
# array([2102, 2129, 2092, 2151, 2077, 1960, 1704, 1360, 1070,  843,  646,
#         476,  391,  291,  258,  325,  375,  320,  261,  388,  693, 1042,
#        1273, 1243,  925,  505,  310,  224,  176,  102,   22], dtype=int64)
