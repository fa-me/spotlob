# %%
import sys
sys.path.append("..")

# %%
# %matplotlib notebook

# %%
from spotlob.defaults import *

# %%
gui = make_gui("../spotlob/tests/resources/testdata3.jpg")

# %%
show_gui(gui)
# Out:
# <img src="data:image/png;base64,..." width="800">
# ...
# Button(description='Evaluate', style=ButtonStyle())
