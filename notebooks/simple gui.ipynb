# %%
import sys
sys.path.append("..")

# %%
# %matplotlib notebook

# %%
import spotlob
from spotlob.defaults import *

# %%
filename = "testdata5.JPG"

# %%
gui = make_gui(filename)

# %%
show_gui(gui)
# Out:
# <img src="data:image/png;base64,..." width="465">
# ...
# Button(description='Evaluate', style=ButtonStyle())

# %%
results = gui.results()

# %%
results.describe()
# Out:
#           area_px2  ellipse_majorAxis_px  ellipse_minorAxis_px  ellipse_angle
# count    24.000000             24.000000             24.000000      24.000000
# mean   8357.437500             99.977841            107.283531      61.057213
# std     206.741138              1.511965              0.826629       5.116583
# min    7801.500000             96.042732            105.939255      50.546848
# 25%    8294.375000             99.285997            106.726557      57.482067
# 50%    8360.750000            100.128189            107.142494      61.743946
# 75%    8463.000000            100.620197            107.859777      63.983205
# max    8833.500000            104.056252            108.772003      73.817223

# %%
results.hist("area_px2")
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B1ACF98>]],
#       dtype=object)

# %%
gui.pipeline.save?
